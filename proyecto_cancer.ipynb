# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./files/Breast_Cancer.csv')
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
df.rename(columns={"Reginol Node Positive": "Regional Node Positive"}, inplace=True)

# %%
df.to_csv('./clean files/Breast_Cancer_Limpio.csv', index=False)

# %%
df_continentes = pd.read_csv('./files/dataset-continentes.csv')
df_continentes
# Out:
#   Alpha-3 code  Cancer code  Population code (ISO/UN)  Country  \
# 0         N.A.         20.0                     903.0    903.0
# 1         N.A.         20.0                     904.0    904.0
# 2         N.A.         20.0                     905.0    905.0
# 3         N.A.         20.0                     908.0    908.0
# 4         N.A.         20.0                     909.0    909.0
# 5         N.A.         20.0                     935.0    935.0
# 6          NaN          NaN                       NaN      NaN
#
#                              Label  Sex   Number  95% UI low  95% UI high  \
# 0                           Africa  2.0   198553    196356.0     200774.0
# 1  Latin America and the Caribbean  2.0   220124    218440.0     221821.0
# 2                 Northern America  2.0   306307    305083.0     307536.0
# 3                           Europe  2.0   557532    554385.0     560696.0
# 4                          Oceania  2.0    28507     28057.0      28964.0
# ...

# %%
df_continentes.isnull().sum()
# Out:
# Alpha-3 code                1
# Cancer code                 1
# Population code (ISO/UN)    1
# Country                     1
# Label                       0
# Sex                         1
# Number                      0
# 95% UI low                  1
# 95% UI high                 1
# Number.1                    0
# ASR (World)                 0
# Crude rate                  0
# Cumulative risk             0
# dtype: int64

# %%
# Borramos la ultima fila, que es la que contiene los nulos
df_continentes = df_continentes.iloc[:-1]
df_continentes
# Out:
#   Alpha-3 code  Cancer code  Population code (ISO/UN)  Country  \
# 0         N.A.         20.0                     903.0    903.0
# 1         N.A.         20.0                     904.0    904.0
# 2         N.A.         20.0                     905.0    905.0
# 3         N.A.         20.0                     908.0    908.0
# 4         N.A.         20.0                     909.0    909.0
# 5         N.A.         20.0                     935.0    935.0
#
#                              Label  Sex  Number  95% UI low  95% UI high  \
# 0                           Africa  2.0  198553    196356.0     200774.0
# 1  Latin America and the Caribbean  2.0  220124    218440.0     221821.0
# 2                 Northern America  2.0  306307    305083.0     307536.0
# 3                           Europe  2.0  557532    554385.0     560696.0
# 4                          Oceania  2.0   28507     28057.0      28964.0
# 5                             Asia  2.0  985817    981692.0     989960.0
#
# ...

# %%
# Borramos las columnas que no necesitamos
df_continentes.drop(columns=['Alpha-3 code', 'Cancer code', 'Population code (ISO/UN)', 'Country', 'Sex', '95% UI low', '95% UI high', 'Number.1'], inplace=True)
# Out:
# C:\Users\nadal\AppData\Local\Temp\ipykernel_10380\3129354728.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_continentes.drop(columns=['Alpha-3 code', 'Cancer code', 'Population code (ISO/UN)', 'Country', 'Sex', '95% UI low', '95% UI high', 'Number.1'], inplace=True)

# %%
df_continentes
# Out:
#                              Label  Number  ASR (World)  Crude rate  \
# 0                           Africa  198553         40.5        28.2
# 1  Latin America and the Caribbean  220124         52.0        65.1
# 2                 Northern America  306307         95.1       162.5
# 3                           Europe  557532         75.6       144.3
# 4                          Oceania   28507         91.5       130.5
# 5                             Asia  985817         34.3        43.4
#
#    Cumulative risk
# 0              4.3
# 1              5.6
# 2             10.3
# 3              8.1
# 4              9.9
# 5              3.7

# %%
# Cambiamos el nombre de algunas columnas para que sea más intuitivo
df_continentes.rename(columns={"Label": "Continent", "Number": "Total Cases", "ASR (World)": "Age-Standardized Rate"}, inplace=True)
df_continentes
# Out:
# C:\Users\nadal\AppData\Local\Temp\ipykernel_10380\3615531090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_continentes.rename(columns={"Label": "Continent", "Number": "Total Cases", "ASR (World)": "Age-Standardized Rate"}, inplace=True)
#                          Continent  Total Cases  Age-Standardized Rate  \
# 0                           Africa       198553                   40.5
# 1  Latin America and the Caribbean       220124                   52.0
# 2                 Northern America       306307                   95.1
# 3                           Europe       557532                   75.6
# 4                          Oceania        28507                   91.5
# 5                             Asia       985817                   34.3
#
#    Crude rate  Cumulative risk
# ...

# %%
# Guardamos el archivo limpio
df_continentes.to_csv('./clean files/dataset-continentes-limpio.csv', index=False)

# %%
# Leemos el archivo de países  
df_paises = pd.read_csv('./files/dataset-paises.csv')
df_paises
# Out:
#     Alpha-3 code  Cancer code  Population code (ISO/UN)  Country  \
# 0            AFG         20.0                       4.0      4.0
# 1            ALB         20.0                       8.0      8.0
# 2            DZA         20.0                      12.0     12.0
# 3            AGO         20.0                      24.0     24.0
# 4            AZE         20.0                      31.0     31.0
# ..           ...          ...                       ...      ...
# 233         N.A.         20.0                     993.0    993.0
# 234         N.A.         20.0                     994.0    994.0
# 235         N.A.         20.0                     995.0    995.0
# 236         N.A.         20.0                     996.0    996.0
# 237          NaN          NaN                       NaN      NaN
#
#                                     Label  Sex    Number  95% UI low  \
# 0                             Afghanistan  0.0      3545      1678.0
# ...

# %%
df_paises.isnull().sum()
# Out:
# Alpha-3 code                1
# Cancer code                 1
# Population code (ISO/UN)    1
# Country                     1
# Label                       0
# Sex                         1
# Number                      0
# 95% UI low                  1
# 95% UI high                 1
# Number.1                    0
# ASR (World)                 0
# Crude rate                  0
# Cumulative risk             0
# dtype: int64

# %%
# Borramos la ultima fila, que es la que contiene los nulos
df_paises = df_paises.iloc[:-1]
df_paises
# Out:
#     Alpha-3 code  Cancer code  Population code (ISO/UN)  Country  \
# 0            AFG         20.0                       4.0      4.0
# 1            ALB         20.0                       8.0      8.0
# 2            DZA         20.0                      12.0     12.0
# 3            AGO         20.0                      24.0     24.0
# 4            AZE         20.0                      31.0     31.0
# ..           ...          ...                       ...      ...
# 232         N.A.         20.0                     992.0    992.0
# 233         N.A.         20.0                     993.0    993.0
# 234         N.A.         20.0                     994.0    994.0
# 235         N.A.         20.0                     995.0    995.0
# 236         N.A.         20.0                     996.0    996.0
#
#                                     Label  Sex  Number  95% UI low  \
# 0                             Afghanistan  0.0    3545      1678.0
# ...

# %%
df_paises.isnull().sum()
# Out:
# Alpha-3 code                0
# Cancer code                 0
# Population code (ISO/UN)    0
# Country                     0
# Label                       0
# Sex                         0
# Number                      0
# 95% UI low                  0
# 95% UI high                 0
# Number.1                    0
# ASR (World)                 0
# Crude rate                  0
# Cumulative risk             0
# dtype: int64

# %%
# Borramos las columnas que no necesitamos
df_paises.drop(columns=['Alpha-3 code', 'Cancer code', 'Population code (ISO/UN)', 'Country', 'Sex', '95% UI low', '95% UI high', 'Number.1'], inplace=True)
df_paises
# Out:
# C:\Users\nadal\AppData\Local\Temp\ipykernel_10380\2336324044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_paises.drop(columns=['Alpha-3 code', 'Cancer code', 'Population code (ISO/UN)', 'Country', 'Sex', '95% UI low', '95% UI high', 'Number.1'], inplace=True)
#                                     Label  Number  ASR (World)  Crude rate  \
# 0                             Afghanistan    3545         29.4        17.9
# 1                                 Albania    1022         51.1        72.6
# 2                                 Algeria   14601         61.9        65.1
# 3                                  Angola    2898         29.4        16.4
# 4                              Azerbaijan    2195         32.9        42.6
# ...

# %%
# Cambiamos el nombre de algunas columnas para que sea más intuitivo
df_paises.rename(columns={"Label": "Country", "Number": "Total Cases", "ASR (World)": "Age-Standardized Rate"}, inplace=True)
df_paises
# Out:
# C:\Users\nadal\AppData\Local\Temp\ipykernel_10380\296247649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_paises.rename(columns={"Label": "Country", "Number": "Total Cases", "ASR (World)": "Age-Standardized Rate"}, inplace=True)
#                                   Country  Total Cases  Age-Standardized Rate  \
# 0                             Afghanistan         3545                   29.4
# 1                                 Albania         1022                   51.1
# 2                                 Algeria        14601                   61.9
# 3                                  Angola         2898                   29.4
# 4                              Azerbaijan         2195                   32.9
# ..                                    ...          ...                    ...
# ...

# %%
# Guardamos el archivo limpio
df_paises.to_csv('./clean files/dataset-paises-limpio.csv', index=False)
